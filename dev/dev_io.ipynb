# %% [markdown]
# #

# %%
# !uv pip install jupyterlab-vim
# Out:
# Using Python 3.12.9 environment at: C:\Users\RBO\repos\mbo_utilities\.venv
# Resolved 93 packages in 266ms
# Prepared 1 package in 30ms
# Installed 1 package in 31ms
#  + jupyterlab-vim==4.1.4

# %%
from pathlib import Path
import mbo_utilities as mbo
# from mbo_utilities.graphics.run_gui import run_gui

# %%
data = mbo.imread("D:/demo/raw")
# Out:
# Counting frames:   0%|          | 0/2 [00:00<?, ?it/s]

# %%
import lbm_suite2p_python as lsp

ops = {
    "anatomical_only": 3,
    "diameter": 4,
    "cellprob_threshold": -6,
    "two_step_registration": 1,
}
lsp.run_volume(
    data,
    r"D:/demo/raw/temp"
)
# Out:
# Processing 14 planes in volume (Total planes: 14)
# Output: D:\demo\raw\temp
# Importing suite2p packages...
#
# --- Volume Step: Plane 1 ---
# Importing suite2p packages...
# Writing binary to D:\demo\raw\temp\zplane01_tp00001-01574...
# NOTE: applying default C:\Users\RBO\.suite2p\classifiers\classifier_user.npy
# ----------- REGISTRATION
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[3], line 9
#       5     "diameter": 4,
#       6     "cellprob_threshold": -6,
#       7     "two_step_registration": 1,
#       8 }
# ----> 9 lsp.run_volume(
#      10     data,
#      11     r"D:/demo/raw/temp"
#      12 )
#
# File c:\Users\RBO\repos\mbo_utilities\.venv\Lib\site-packages\lbm_suite2p_python\run_lsp.py:843, in run_volume(input_data, save_path, ops, planes, keep_reg, keep_raw, force_reg, force_detect, frame_indices, dff_window_size, dff_percentile, dff_smooth_window, accept_all_cells, cell_filters, save_json, reader_kwargs, writer_kwargs, **kwargs)
#     841 try:
#     842     print(f"\n--- Volume Step: Plane {plane_num} ---")
# --> 843     ops_file = run_plane(
#     844         input_data=current_input,
#     845         save_path=save_path,
#     846         ops=current_ops,
#     847         keep_reg=keep_reg,
#     848         keep_raw=keep_raw,
#     849         force_reg=force_reg,
#     850         force_detect=force_detect,
#     851         frame_indices=frame_indices,
#     852         dff_window_size=dff_window_size,
#     853         dff_percentile=dff_percentile,
#     854         dff_smooth_window=dff_smooth_window,
#     855         accept_all_cells=accept_all_cells,
#     856         cell_filters=cell_filters,
#     857         save_json=save_json,
#     858         reader_kwargs=reader_kwargs,
#     859         writer_kwargs=writer_kwargs,
#     860         **kwargs,
#     861     )
#     862     ops_files.append(ops_file)
#     864     if progress_callback:
#
# File c:\Users\RBO\repos\mbo_utilities\.venv\Lib\site-packages\lbm_suite2p_python\run_lsp.py:2025, in run_plane(input_data, save_path, ops, chan2_file, keep_raw, keep_reg, force_reg, force_detect, frame_indices, dff_window_size, dff_percentile, dff_smooth_window, accept_all_cells, cell_filters, save_json, plane_name, reader_kwargs, writer_kwargs, **kwargs)
#    2023 try:
#    2024     s2p_start = time.time()
# -> 2025     processed = run_plane_bin(ops)
#    2027     if processed:
#    2028         updated_ops = load_ops(ops_file)
#
# File c:\Users\RBO\repos\mbo_utilities\.venv\Lib\site-packages\lbm_suite2p_python\run_lsp.py:1418, in run_plane_bin(ops)
#    1408         ops = pipeline(
#    1409             f_reg=f_reg,
#    1410             f_raw=f_raw,
#    (...)   1415             stat=None,
#    1416         )
#    1417     else:
# -> 1418         ops = pipeline(
#    1419             f_reg=f_reg,
#    1420             f_raw=f_raw,
#    1421             f_reg_chan2=f_reg_chan2 if use_chan2 else None,
#    1422             f_raw_chan2=f_raw_chan2 if use_chan2 else None,
#    1423             run_registration=run_registration,
#    1424             ops=ops,
#    1425             stat=None,
#    1426         )
#    1428 # ensure meanImgE is always present in final ops (safety net)
#    1429 if "meanImgE" not in ops and "meanImg" in ops:
#
# File c:\Users\RBO\repos\mbo_utilities\.venv\Lib\site-packages\suite2p\run_s2p.py:114, in pipeline(f_reg, f_raw, f_reg_chan2, f_raw_chan2, run_registration, ops, stat)
#     110 refImg = ops["refImg"] if "refImg" in ops and ops.get("force_refImg",
#     111                                                       False) else None
#     113 align_by_chan2 = ops["functional_chan"] != ops["align_by_chan"]
# --> 114 registration_outputs = registration.registration_wrapper(
#     115     f_reg, f_raw=f_raw, f_reg_chan2=f_reg_chan2, f_raw_chan2=f_raw_chan2,
#     116     refImg=refImg, align_by_chan2=align_by_chan2, ops=ops)
#     118 ops = registration.save_registration_outputs_to_ops(registration_outputs, ops)
#     119 # add enhanced mean image
#
# File c:\Users\RBO\repos\mbo_utilities\.venv\Lib\site-packages\suite2p\registration\register.py:642, in registration_wrapper(f_reg, f_raw, f_reg_chan2, f_raw_chan2, refImg, align_by_chan2, ops)
#     639 else:
#     640     nchannels = 1
# --> 642 outputs = compute_reference_and_register_frames(f_align_in, f_align_out=f_align_out,
#     643                                                 refImg=refImg, ops=ops)
#     644 refImg, rmin, rmax, mean_img, rigid_offsets, nonrigid_offsets, zest = outputs
#     645 yoff, xoff, corrXY = rigid_offsets
#
# File c:\Users\RBO\repos\mbo_utilities\.venv\Lib\site-packages\suite2p\registration\register.py:412, in compute_reference_and_register_frames(f_align_in, f_align_out, refImg, ops)
#     410     if refImg is None:
#     411         t0 = time.time()
# --> 412         refImg = compute_reference(frames, ops=ops)
#     413         print("Reference frame, %0.2f sec." % (time.time() - t0))
#     415 if isinstance(refImg, list):
#
# File c:\Users\RBO\repos\mbo_utilities\.venv\Lib\site-packages\suite2p\registration\register.py:140, in compute_reference(frames, ops)
#     137 niter = 8
#     138 for iter in range(0, niter):
#     139     # rigid registration
# --> 140     ymax, xmax, cmax = rigid.phasecorr(
#     141         data=rigid.apply_masks(
#     142             frames,
#     143             *rigid.compute_masks(
#     144                 refImg=refImg,
#     145                 maskSlope=ops["spatial_taper"] if ops["1Preg"] else 3 *
#     146                 ops["smooth_sigma"],
#     147             )),
#     148         cfRefImg=rigid.phasecorr_reference(
#     149             refImg=refImg,
#     150             smooth_sigma=ops["smooth_sigma"],
#     151         ),
#     152         maxregshift=ops["maxregshift"],
#     153         smooth_sigma_time=ops["smooth_sigma_time"],
#     154     )
#     155     for frame, dy, dx in zip(frames, ymax, xmax):
#     156         frame[:] = rigid.shift_frame(frame=frame, dy=dy, dx=dx)
#
# File c:\Users\RBO\repos\mbo_utilities\.venv\Lib\site-packages\suite2p\registration\rigid.py:98, in phasecorr(data, cfRefImg, maxregshift, smooth_sigma_time)
#      95 lcorr = int(np.minimum(np.round(maxregshift * min_dim), min_dim // 2))
#      97 #cc = convolve(data, cfRefImg, lcorr)
# ---> 98 data = convolve(data, cfRefImg)
#      99 cc = np.real(
#     100     np.block([[data[:, -lcorr:, -lcorr:], data[:, -lcorr:, :lcorr + 1]],
#     101               [data[:, :lcorr + 1, -lcorr:], data[:, :lcorr + 1, :lcorr + 1]]]))
#     103 cc = temporal_smooth(cc, smooth_sigma_time) if smooth_sigma_time > 0 else cc
#
# File c:\Users\RBO\repos\mbo_utilities\.venv\Lib\site-packages\suite2p\registration\utils.py:34, in convolve(mov, img)
#      19 def convolve(mov: np.ndarray, img: np.ndarray) -> np.ndarray:
#      20     """
#      21     Returns the 3D array "mov" convolved by a 2D array "img".
#      22
#    (...)     32     convolved_data: nImg x Ly x Lx
#      33     """
# ---> 34     return ifft2(apply_dotnorm(fft2(mov), img))
#
# KeyboardInterrupt:

# %%
inpath = r"D:\W2_DATA\kbarber\07_27_2025\mk355\green"

iw = run_gui(inpath)
# Out:
# Counting frames:   0%|          | 0/248 [00:00<?, ?it/s]
# RFBOutputContext()
# Num rois: 2
# zstats: [{'mean': [], 'std': [], 'snr': []}, {'mean': [], 'std': [], 'snr': []}]
# Counting frames:   0%|          | 0/248 [00:00<?, ?it/s]
# Counting frames:   0%|          | 0/248 [00:00<?, ?it/s]

# %%
inpath = r"D:\W2_DATA\kbarber\07_27_2025\mk355\green"
arr = mbo.imread(inpath)
arr.use_fft = True
print(arr.shape)

mbo.imwrite(
    arr,
    r"E:\tests\lbm\deepcaimx\data",
    num_frames=1000,
    register_z=False,
    planes=[7, 8, 9],
    overwrite=True,
    # ext=".t"
)
test_arr = mbo.imread(r"D:\W2_DATA\kbarber\07_27_2025\mk355\green\temp\plane01_stitched.tif")
print(test_arr.shape)
# Out:
# Counting frames:   0%|          | 0/248 [00:00<?, ?it/s]
# (52106, 14, 550, 448)
# Saving plane07_stitched.tiff:   0%|          | 0/24 [00:00<?, ?it/s]
# DEBUG _write_tiff: Writing 42 frames to plane07_stitched.tif, is_new_session=True
# DEBUG _write_tiff: Writing 42 frames to plane07_stitched.tif, is_new_session=False
# DEBUG _write_tiff: Writing 42 frames to plane07_stitched.tif, is_new_session=False
# DEBUG _write_tiff: Writing 42 frames to plane07_stitched.tif, is_new_session=False
# DEBUG _write_tiff: Writing 42 frames to plane07_stitched.tif, is_new_session=False
# DEBUG _write_tiff: Writing 42 frames to plane07_stitched.tif, is_new_session=False
# DEBUG _write_tiff: Writing 42 frames to plane07_stitched.tif, is_new_session=False
# DEBUG _write_tiff: Writing 42 frames to plane07_stitched.tif, is_new_session=False
# DEBUG _write_tiff: Writing 42 frames to plane07_stitched.tif, is_new_session=False
# DEBUG _write_tiff: Writing 42 frames to plane07_stitched.tif, is_new_session=False
# DEBUG _write_tiff: Writing 42 frames to plane07_stitched.tif, is_new_session=False
# DEBUG _write_tiff: Writing 42 frames to plane07_stitched.tif, is_new_session=False
# DEBUG _write_tiff: Writing 42 frames to plane07_stitched.tif, is_new_session=False
# DEBUG _write_tiff: Writing 42 frames to plane07_stitched.tif, is_new_session=False
# DEBUG _write_tiff: Writing 42 frames to plane07_stitched.tif, is_new_session=False
# DEBUG _write_tiff: Writing 42 frames to plane07_stitched.tif, is_new_session=False
# DEBUG _write_tiff: Writing 41 frames to plane07_stitched.tif, is_new_session=False
# DEBUG _write_tiff: Writing 41 frames to plane07_stitched.tif, is_new_session=False
# DEBUG _write_tiff: Writing 41 frames to plane07_stitched.tif, is_new_session=False
# DEBUG _write_tiff: Writing 41 frames to plane07_stitched.tif, is_new_session=False
# DEBUG _write_tiff: Writing 41 frames to plane07_stitched.tif, is_new_session=False
# DEBUG _write_tiff: Writing 41 frames to plane07_stitched.tif, is_new_session=False
# DEBUG _write_tiff: Writing 41 frames to plane07_stitched.tif, is_new_session=False
# DEBUG _write_tiff: Writing 41 frames to plane07_stitched.tif, is_new_session=False
# Saving plane08_stitched.tiff:   0%|          | 0/24 [00:00<?, ?it/s]
# DEBUG _write_tiff: Writing 42 frames to plane08_stitched.tif, is_new_session=True
# DEBUG _write_tiff: Writing 42 frames to plane08_stitched.tif, is_new_session=False
# DEBUG _write_tiff: Writing 42 frames to plane08_stitched.tif, is_new_session=False
# DEBUG _write_tiff: Writing 42 frames to plane08_stitched.tif, is_new_session=False
# DEBUG _write_tiff: Writing 42 frames to plane08_stitched.tif, is_new_session=False
# DEBUG _write_tiff: Writing 42 frames to plane08_stitched.tif, is_new_session=False
# DEBUG _write_tiff: Writing 42 frames to plane08_stitched.tif, is_new_session=False
# DEBUG _write_tiff: Writing 42 frames to plane08_stitched.tif, is_new_session=False
# DEBUG _write_tiff: Writing 42 frames to plane08_stitched.tif, is_new_session=False
# DEBUG _write_tiff: Writing 42 frames to plane08_stitched.tif, is_new_session=False
# DEBUG _write_tiff: Writing 42 frames to plane08_stitched.tif, is_new_session=False
# DEBUG _write_tiff: Writing 42 frames to plane08_stitched.tif, is_new_session=False
# DEBUG _write_tiff: Writing 42 frames to plane08_stitched.tif, is_new_session=False
# DEBUG _write_tiff: Writing 42 frames to plane08_stitched.tif, is_new_session=False
# DEBUG _write_tiff: Writing 42 frames to plane08_stitched.tif, is_new_session=False
# DEBUG _write_tiff: Writing 42 frames to plane08_stitched.tif, is_new_session=False
# DEBUG _write_tiff: Writing 41 frames to plane08_stitched.tif, is_new_session=False
# DEBUG _write_tiff: Writing 41 frames to plane08_stitched.tif, is_new_session=False
# DEBUG _write_tiff: Writing 41 frames to plane08_stitched.tif, is_new_session=False
# DEBUG _write_tiff: Writing 41 frames to plane08_stitched.tif, is_new_session=False
# DEBUG _write_tiff: Writing 41 frames to plane08_stitched.tif, is_new_session=False
# DEBUG _write_tiff: Writing 41 frames to plane08_stitched.tif, is_new_session=False
# DEBUG _write_tiff: Writing 41 frames to plane08_stitched.tif, is_new_session=False
# DEBUG _write_tiff: Writing 41 frames to plane08_stitched.tif, is_new_session=False
# Saving plane09_stitched.tiff:   0%|          | 0/24 [00:00<?, ?it/s]
# DEBUG _write_tiff: Writing 42 frames to plane09_stitched.tif, is_new_session=True
# DEBUG _write_tiff: Writing 42 frames to plane09_stitched.tif, is_new_session=False
# DEBUG _write_tiff: Writing 42 frames to plane09_stitched.tif, is_new_session=False
# DEBUG _write_tiff: Writing 42 frames to plane09_stitched.tif, is_new_session=False
# DEBUG _write_tiff: Writing 42 frames to plane09_stitched.tif, is_new_session=False
# DEBUG _write_tiff: Writing 42 frames to plane09_stitched.tif, is_new_session=False
# DEBUG _write_tiff: Writing 42 frames to plane09_stitched.tif, is_new_session=False
# DEBUG _write_tiff: Writing 42 frames to plane09_stitched.tif, is_new_session=False
# DEBUG _write_tiff: Writing 42 frames to plane09_stitched.tif, is_new_session=False
# DEBUG _write_tiff: Writing 42 frames to plane09_stitched.tif, is_new_session=False
# DEBUG _write_tiff: Writing 42 frames to plane09_stitched.tif, is_new_session=False
# DEBUG _write_tiff: Writing 42 frames to plane09_stitched.tif, is_new_session=False
# DEBUG _write_tiff: Writing 42 frames to plane09_stitched.tif, is_new_session=False
# DEBUG _write_tiff: Writing 42 frames to plane09_stitched.tif, is_new_session=False
# DEBUG _write_tiff: Writing 42 frames to plane09_stitched.tif, is_new_session=False
# DEBUG _write_tiff: Writing 42 frames to plane09_stitched.tif, is_new_session=False
# DEBUG _write_tiff: Writing 41 frames to plane09_stitched.tif, is_new_session=False
# DEBUG _write_tiff: Writing 41 frames to plane09_stitched.tif, is_new_session=False
# DEBUG _write_tiff: Writing 41 frames to plane09_stitched.tif, is_new_session=False
# DEBUG _write_tiff: Writing 41 frames to plane09_stitched.tif, is_new_session=False
# DEBUG _write_tiff: Writing 41 frames to plane09_stitched.tif, is_new_session=False
# DEBUG _write_tiff: Writing 41 frames to plane09_stitched.tif, is_new_session=False
# DEBUG _write_tiff: Writing 41 frames to plane09_stitched.tif, is_new_session=False
# DEBUG _write_tiff: Writing 41 frames to plane09_stitched.tif, is_new_session=False
# Counting frames:   0%|          | 0/1 [00:00<?, ?it/s]
# (1000, 1, 550, 448)
