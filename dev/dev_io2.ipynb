# %% [markdown]
# # Graphical User Inteface

# %%
# !uv pip install jupyterlab-vim
# !uv pip install wgpu==0.28.1
# Out:
# Using Python 3.12.9 environment at: C:\Users\RBO\repos\mbo_utilities\.venv
# Audited 1 package in 30ms
# Using Python 3.12.9 environment at: C:\Users\RBO\repos\mbo_utilities\.venv
# Audited 1 package in 15ms

# %%
from pathlib import Path
import mbo_utilities as mbo
from mbo_utilities.graphics.run_gui import run_gui

# %%
data_path = r"D:\W2_DATA\foconnell\isoview_development\mosquito-larva_20250930_165806.corrected_python_zarr\TM000000\SPM00_TM000000_CM02_CHN01.zarr"

# %%
iw = run_gui(data_path)
iw.show()
# Out:
# INFO - mbo.lazy_array - Detected zarr.json, loading as ZarrArray.
# RFBOutputContext()
# INFO - mbo.gui - Logger initialized.
# INFO - mbo.gui - Logger initialized.
# INFO - mbo.gui - Starting zstats computation in a separate thread.
# INFO - mbo.gui - Starting zstats computation in a separate thread.
# JupyterRenderCanvas(css_height='800.0px', css_width='800.0px')

# %%
# !uv pip install wgpu==0.28.1
# Out:
# Using Python 3.12.9 environment at: C:\Users\RBO\repos\mbo_utilities\.venv
# Audited 1 package in 16ms

# %%
iw.show()
# Out:
# Using Python 3.12.9 environment at: C:\Users\RBO\repos\mbo_utilities\.venv
# Resolved 5 packages in 8ms
# Uninstalled 1 package in 13ms
# Installed 1 package in 22ms
#  - wgpu==0.25.0
#  + wgpu==0.28.1
# Draw error: 'WgpuContextToBitmap' object has no attribute 'canvas' (3)
# JupyterRenderCanvas(css_height='800.0px', css_width='800.0px', frame_feedback={'index': 2, 'timestamp': 176401…
