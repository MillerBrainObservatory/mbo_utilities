# %%
from pathlib import Path
import mbo_utilities as mbo

matpath = Path(r"D:\W2_DATA\wsynder")
files = mbo.get_files(matpath, ".mat")
files
# Out:
# [WindowsPath('D:/W2_DATA/wsynder/Left-trials-stim-before.mat'),
#  WindowsPath('D:/W2_DATA/wsynder/FrameMatched3169025.mat')]

# %%
import scipy.io
left_trials = scipy.io.loadmat(files[0])
frame_matched = scipy.io.loadmat(files[1])
print(frame_matched.keys())
print(left_trials.keys())
# Out:
# dict_keys(['__header__', '__version__', '__globals__', 'None', '__function_workspace__'])
# dict_keys(['__header__', '__version__', '__globals__', 'LTS', '__function_workspace__'])

# %%
lts_data = left_trials['LTS']
frame_data = frame_matched['None']

print(f"LTS shape: {lts_data.shape}, dtype: {lts_data.dtype}")
print(f"Frame matched shape: {frame_data.shape}, dtype: {frame_data.dtype}")
# Out:
# LTS shape: (1, 1), dtype: [('Stim_On', 'O'), ('Before', 'O'), ('After', 'O')]
# Frame matched shape: (1,), dtype: [('s0', 'O'), ('s1', 'O'), ('s2', 'O'), ('arr', 'O')]

# %%
dir(frame_matched)
# Out:
# ['__class__',
#  '__class_getitem__',
#  '__contains__',
#  '__delattr__',
#  '__delitem__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__ior__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__ne__',
#  '__new__',
#  '__or__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__reversed__',
#  '__ror__',
#  '__setattr__',
#  '__setitem__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'clear',
#  'copy',
#  'fromkeys',
#  'get',
#  'items',
#  'keys',
#  'pop',
#  'popitem',
#  'setdefault',
#  'update',
#  'values']

# %%
# Out:
# b'MATLAB 5.0 MAT-file, Platform: MACA64, Created on: Thu Nov  6 16:58:34 2025'
# 1.0
# []
# [(b'Data_Table', b'MCOS', b'table', array([[3707764736],
#         [         2],
#         [         1],
#         [         1],
#         [         1],
#         [         2]], dtype=uint32))                   ]
# [[ 0  1 73 ...  0  0  0]]

# %%
for k in frame_matched.keys():
    print(frame_matched[k])

for k in left_trials.keys():
    print(left_trials[k])
# Out:
# b'MATLAB 5.0 MAT-file, Platform: MACA64, Created on: Thu Nov  6 16:58:34 2025'
# 1.0
# []
# [(b'Data_Table', b'MCOS', b'table', array([[3707764736],
#         [         2],
#         [         1],
#         [         1],
#         [         1],
#         [         2]], dtype=uint32))                   ]
# [[ 0  1 73 ...  0  0  0]]
# b'MATLAB 5.0 MAT-file, Platform: MACA64, Created on: Wed Nov 12 16:35:54 2025'
# 1.0
# []
# [[(MatlabOpaque([(b'', b'MCOS', b'table', array([[3707764736],
#                        [         2],
#                        [         1],
#                        [         1],
#                        [         1],
#                        [         2]], dtype=uint32))         ],
#                dtype=[('s0', 'O'), ('s1', 'O'), ('s2', 'O'), ('arr', 'O')]), MatlabOpaque([(b'', b'MCOS', b'table', array([[3707764736],
#                        [         2],
#                        [         1],
#                        [         1],
# ...

# %%
# !uv pip install mat73
# Out:
# Using Python 3.12.9 environment at: C:\Users\RBO\repos\mbo_utilities\.venv
# Resolved 3 packages in 1.06s
# Prepared 1 package in 18ms
# Installed 1 package in 6ms
#  + mat73==0.65

# %%
import mat73

left_trials = mat73.loadmat(files[0])
frame_matched = mat73.loadmat(files[1])

# Now explore what's actually in there
print(left_trials.keys())
print(frame_matched.keys())

# Look at the actual data structure
for k in left_trials.keys():
    if not k.startswith('__'):
        print(f"\n{k}:")
        print(type(left_trials[k]))
        if hasattr(left_trials[k], 'keys'):
            print(left_trials[k].keys())
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# File c:\Users\RBO\repos\mbo_utilities\.venv\Lib\site-packages\mat73\core.py:346, in loadmat(file, use_attrdict, only_include, verbose)
#     345 try:
# --> 346     with h5py.File(file, 'r') as hdf5:
#     347         dictionary = decoder.mat2dict(hdf5)
#
# File c:\Users\RBO\repos\mbo_utilities\.venv\Lib\site-packages\h5py\_hl\files.py:566, in File.__init__(self, name, mode, driver, libver, userblock_size, swmr, rdcc_nslots, rdcc_nbytes, rdcc_w0, track_order, fs_strategy, fs_persist, fs_threshold, fs_page_size, page_buf_size, min_meta_keep, min_raw_keep, locking, alignment_threshold, alignment_interval, meta_block_size, track_times, **kwds)
#     563     fcpl = make_fcpl(track_order=track_order, track_times=track_times,
#     564                      fs_strategy=fs_strategy, fs_persist=fs_persist,
# ...
