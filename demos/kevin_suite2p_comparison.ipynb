# %%
# !uv pip install jupyterlab-vim
# Out:
# Using Python 3.12.9 environment at: C:\Users\RBO\repos\mbo_utilities\.venv
# Resolved 92 packages in 138ms
# Installed 1 package in 72ms
#  + jupyterlab-vim==4.1.4

# %%
# !uv pip install ../../LBM-Suite2p-Python
# Out:
# Using Python 3.12.9 environment at: C:\Users\RBO\repos\mbo_utilities\.venv
# Resolved 158 packages in 532ms
#    Building lbm-suite2p-python @ file:///C:/Users/RBO/repos/LBM-Suite2p-Python
#       Built lbm-suite2p-python @ file:///C:/Users/RBO/repos/LBM-Suite2p-Python
# Prepared 1 package in 1.19s
# Uninstalled 1 package in 3ms
# Installed 1 package in 8ms
#  ~ lbm-suite2p-python==2.3.1 (from file:///C:/Users/RBO/repos/LBM-Suite2p-Python)

# %%
import mbo_utilities as mbo
from mbo_utilities.widgets import select_file
from pathlib import Path
import fastplotlib as fpl
from ipywidgets import VBox
import lbm_suite2p_python as lsp
# Out:
# Image(value=b'version https://git-lfs.github.com/spec/...', height='55', width='300')
# <b>Available devices:</b><table><tr><th>Valid</th><th>Device</th><th>Type</th><th>Backend</th><th>Driver</th></tr><tr title="This adapter can be used with fastplotlib"><td>✅ (default) </td><td>NVIDIA RTX A4000</td><td>DiscreteGPU</td><td>Vulkan</td><td>553.09</td></tr><tr title="This adapter can be used with fastplotlib"><td>✅</td><td>NVIDIA RTX A4000</td><td>DiscreteGPU</td><td>D3D12</td><td></td></tr><tr title="This adapter can be used with fastplotlib"><td>✅</td><td>NVIDIA RTX A4000</td><td>DiscreteGPU</td><td>D3D12</td><td></td></tr><tr title="CPU rendering support is limited and mainly for testing purposes"><td>❗ limited</td><td>Microsoft Basic Render Driver</td><td>CPU</td><td>D3D12</td><td></td></tr><tr title="This adapter cannot be used with fastplotlib"><td>❌</td><td>NVIDIA RTX A4000/PCIe/SSE2</td><td>Unknown</td><td>OpenGL</td><td>4.6.0 NVIDIA 553.09</td></tr></table>

# %%
raw_tiffs = Path(r"\\rbo-s1\S1_DATA\lbm\kbarber\2025-11-04-mk311\raw\green")

# %%
data_mbo = mbo.imread(raw_tiffs, fix_phase=True, use_fft=True)
data_mbo.shape
# Out:
# Counting frames:   0%|          | 0/379 [00:00<?, ?it/s]
# (58825, 14, 448, 448)

# %%
OUTPUT_DIR = Path(r"D:/kbarber")

ops_paths = lsp.pipeline(
    input_data=raw_tiffs,
    save_path=OUTPUT_DIR,
    planes=[7],
    num_frames=2000,
    force_reg=True,
    force_detect=True,
    ops={
        "anatomical_only":4,
        "two_step_registration": 1,
        "high_pass":10,
        "diameter": 4,
        "denoise": 1,
        "spatial_hp_cp": 0,
        "cellprob_threshold": -6,
        "accept_all_cells": True,
        "flow_threshold": 0,
    },
    reader_kwargs={
        "fix_phase": True,
        "use_fft": True,
    },
    writer_kwargs={
        "output_suffix": f"_max-proj",
    },
)
# Out:
# Loading input data...
#   Input: \\rbo-s1\S1_DATA\lbm\kbarber\2025-11-04-mk311\raw\green
# Counting frames:   0%|          | 0/379 [00:00<?, ?it/s]
#   Loaded as: MboRawArray
#
# Dataset info:
#   Shape: (58825, 14, 448, 448)
#   Frames: 58825
#   Planes: 14
# Registered 37000/58825 in 577.82s
# Registered 37500/58825 in 587.45s
# Registered 38000/58825 in 594.88s
# Registered 38500/58825 in 602.51s
# Registered 39000/58825 in 609.54s
# Registered 39500/58825 in 616.31s
# Registered 40000/58825 in 623.72s
# Registered 40500/58825 in 631.08s
# Registered 41000/58825 in 638.23s
# Registered 41500/58825 in 645.44s
# Registered 42000/58825 in 653.02s
# Registered 42500/58825 in 660.62s
# Registered 43000/58825 in 668.05s
# Registered 43500/58825 in 675.95s
# Registered 44000/58825 in 683.92s
# Registered 44500/58825 in 692.18s
# Registered 45000/58825 in 699.53s
# Registered 45500/58825 in 707.19s
# Registered 46000/58825 in 914.37s
# Registered 46500/58825 in 1121.50s
# Registered 47000/58825 in 1334.15s
# Registered 47500/58825 in 1537.11s
# Registered 48000/58825 in 1734.42s
# Registered 48500/58825 in 1901.02s
# Registered 49000/58825 in 1908.15s
# Registered 49500/58825 in 1914.72s
# Registered 50000/58825 in 1923.08s
# Registered 50500/58825 in 1929.87s
# Registered 51000/58825 in 1938.31s
# Registered 51500/58825 in 1951.08s
# Registered 52000/58825 in 1957.86s
# Registered 52500/58825 in 1964.26s
# Registered 53000/58825 in 1971.26s
# Registered 53500/58825 in 1978.00s
# Registered 54000/58825 in 1984.85s
# Registered 54500/58825 in 1992.06s
# Registered 55000/58825 in 1999.44s
# Registered 55500/58825 in 2006.54s
# Registered 56000/58825 in 2013.79s
# Registered 56500/58825 in 2020.80s
# Registered 57000/58825 in 2027.32s
# Registered 57500/58825 in 2034.30s
# Registered 58000/58825 in 2041.44s
# Registered 58500/58825 in 2048.24s
# Registered 58825/58825 in 2052.47s
# ----------- Total 2086.53 sec
# Registration metrics, 15.57 sec.
# ----------- ROI DETECTION
# Binning movie in chunks of length 22
# Binned movie of size [2673,422,438] created in 18.83 sec.
# Binned movie denoised (for cell detection only) in 18.52 sec.
# >>>> CELLPOSE finding masks in max_proj
# model_type argument is not used in v4.0.1+. Ignoring this argument...
# !NOTE! diameter set to 4.00 for cell detection with cellpose
# channels deprecated in v4.0.1+. If data contain more than 3 channels, only the first 3 channels will be used
# Resizing is deprecated in v4.0.1+
# >>>> 347 masks detected, median diameter = 9.97
# Detected 347 ROIs, 12.56 sec
# After removing overlaps, 347 ROIs remain
# ----------- Total 53.01 sec.
# ----------- EXTRACTION
# Masks created, 0.43 sec.
# Extracted fluorescence from 347 ROIs in 58825 frames, 29.22 sec.
# ----------- Total 30.12 sec.
# ----------- CLASSIFICATION
# ['compact', 'skew', 'npix_norm']
# NOTE: accept_all_cells=True, marking all ROIs as cells
# ----------- SPIKE DECONVOLUTION
# ----------- Total 0.98 sec.
#   Applying default diameter filter (max 30 µm, pixel_size=2.00 µm/px)
#   Applying cell filters...
# filter_by_max_diameter: removed 6 ROIs (max=15.0px)
# Saved filtered iscell to D:\kbarber\plane07_max-proj\iscell.npy
# apply_filters: 6 total ROIs removed (341/347 cells remaining)
#   Warning: Filter plot failed: [Errno 13] Permission denied: 'D:\\kbarber\\plane07_max-proj'
#   Computing dF/F...
#   Generating plots...
# Plotting results for 341 accepted / 6 rejected ROIs
#   Completed plane07_max-proj in 5362.6s
#
# ============================================================
# Pipeline complete!
#   Processed: 1 planes
#   Time: 5366.0s
#   Output: D:\kbarber
# ============================================================
